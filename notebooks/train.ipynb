# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
token_path = "/content/drive/MyDrive/github/brvc_token.txt"

with open(token_path, "r") as f:
    github_token = f.read().strip()

print("✅ Token loaded (hidden for security)")
# Out:
# ✅ Token loaded (hidden for security)

# %%
# Login using the token
import os

os.environ["GITHUB_TOKEN"] = github_token

# !echo $GITHUB_TOKEN | gh auth login --with-token
# Out:
# The value of the GITHUB_TOKEN environment variable is being used for authentication.
# To have GitHub CLI store credentials instead, first clear the value from the environment.

# %%
# !gh repo clone yamada-sexta/brvc -- --depth 1
# Out:
# fatal: destination path 'brvc' already exists and is not an empty directory.
# failed to run git: exit status 128
